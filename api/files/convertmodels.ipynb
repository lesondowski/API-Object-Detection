# %%
from ultralytics import YOLO
import torch

# %% [markdown]
# - Config

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model_is_path = "AD_YL11s_Seg_1.80.pt"
model_od_path = "AD_YL11s_1.0.pt"

# %% [markdown]
# - Đổi class

# %%
model_is = YOLO(model_is_path)
model_od = YOLO(model_od_path)

# %%
model_od.model.names[0] = "Lon & Chai"

# %%
model_od.names
# Out:
# {0: 'Lon & Chai'}

# %%
model_is.names
# Out:
# {0: 'Thùng Hàng',
#  1: 'Sản phẩm trên Kệ & Khối',
#  2: 'Tủ Lạnh',
#  3: 'POSM/Khung Tranh/Food Menu',
#  4: 'Khối hàng',
#  5: 'Kệ VIP/Kệ Đứng/ Kệ Khách Hàng',
#  6: 'Bảng Hiệu'}

# %% [markdown]
# - Mapping Class segmentation

# %%
model_is.model.names[0] = "Thùng Hàng"
model_is.model.names[1] = "Sản phẩm trên Kệ & Khối"
model_is.model.names[2] = "Tủ Lạnh"
model_is.model.names[3] = "POSM/Khung Tranh/Food Menu"
model_is.model.names[4] = "Khối hàng"
model_is.model.names[5] = "Kệ VIP/Kệ Đứng/ Kệ Khách Hàng"
model_is.model.names[6] = "Bảng Hiệu"

# %%
model_is.names
# Out:
# {0: 'Thùng Hàng',
#  1: 'Sản phẩm trên Kệ & Khối',
#  2: 'Tủ Lạnh',
#  3: 'POSM/Khung Tranh/Food Menu',
#  4: 'Khối hàng',
#  5: 'Kệ VIP/Kệ Đứng/ Kệ Khách Hàng',
#  6: 'Bảng Hiệu'}

# %% [markdown]
# - Save model

# %%
model_is.export(format="onnx")
# Out:
# Ultralytics 8.3.225  Python-3.10.11 torch-2.9.0+cpu CPU (AMD Ryzen 5 5625U with Radeon Graphics)
# YOLO11n-seg summary (fused): 113 layers, 2,835,933 parameters, 0 gradients, 9.6 GFLOPs
#
# PyTorch: starting from 'AD_YL11s_Seg_1.80.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 43, 8400), (1, 32, 160, 160)) (5.7 MB)
#
# ONNX: starting export with onnx 1.13.1 opset 18...
# WARNING ONNX: simplifier failure: FLOAT8E4M3FN
# ONNX: export success  1.9s, saved as 'AD_YL11s_Seg_1.80.onnx' (11.1 MB)
#
# Export complete (2.6s)
# Results saved to D:\AUDIT CA LEE JONG SON\Tengroup\Window-Audit-pipeline\src\api\files
# Predict:         yolo predict task=segment model=AD_YL11s_Seg_1.80.onnx imgsz=640
# Validate:        yolo val task=segment model=AD_YL11s_Seg_1.80.onnx imgsz=640 data=/content/Segmentation-Audit-1/data.yaml
# Visualize:       https://netron.app
# 'AD_YL11s_Seg_1.80.onnx'
