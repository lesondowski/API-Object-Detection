# %% [markdown]
# #### Install

# %%
# !pip install onnx2tf
# !pip install tf_keras
# !pip install sng4onnx
# !pip install onnx_graphsurgeon
# !pip install ai-edge-litert
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (d:\audit của lee jong son\tengroup\window-audit-pipeline\pt2tflite\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\audit của lee jong son\tengroup\window-audit-pipeline\pt2tflite\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\audit của lee jong son\tengroup\window-audit-pipeline\pt2tflite\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\audit của lee jong son\tengroup\window-audit-pipeline\pt2tflite\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\audit của lee jong son\tengroup\window-audit-pipeline\pt2tflite\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\audit của lee jong son\tengroup\window-audit-pipeline\pt2tflite\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %% [markdown]
# #### Convertmodels

# %%
from ultralytics import YOLO
import torch
import tensorflow as tf

# %% [markdown]
# - Config

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model_is_path = "AD_YL11s_Seg_1.80.pt"
model_od_path = "ADYL11m.pt"
model_block_path = "AD_Productblock_YL11.pt"

# %% [markdown]
# #### Đổi class

# %%
model_is = YOLO(model_is_path)
model_od = YOLO(model_od_path)
model_block = YOLO(model_block_path)

# %%
model_block.model.names[0] = "Khối hàng"
model_block.names
model_block.save(model_block_path)

# %%
model_od.model.names[0] = "Lon & Chai"
model_od.names
model_od.save(model_od_path)

# %%
model_is.names
model_is.model.names[0] = "Thùng Hàng"
model_is.model.names[1] = "Sản phẩm trên Kệ & Khối"
model_is.model.names[2] = "Tủ Lạnh"
model_is.model.names[3] = "POSM/Khung Tranh/Food Menu"
model_is.model.names[4] = "Khối hàng"
model_is.model.names[5] = "Kệ VIP/Kệ Đứng/ Kệ Khách Hàng"
model_is.model.names[6] = "Bảng Hiệu"
model_is.names
model_od.save(model_is_path)
# Out:
# {0: 'Thùng Hàng',
#  1: 'Sản phẩm trên Kệ & Khối',
#  2: 'Tủ Lạnh',
#  3: 'POSM/Khung Tranh/Food Menu',
#  4: 'Khối hàng',
#  5: 'Kệ VIP/Kệ Đứng/ Kệ Khách Hàng',
#  6: 'Bảng Hiệu'}
